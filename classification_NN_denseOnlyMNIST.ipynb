# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers
import matplotlib.pyplot as plt

"""
This is a classification model based on NN. Here, we use only dense layers with MNIST dataset.   
Typically M <= N <= K. M is the number of classes. 
N is the number of features in each training or testing example. 
K is the number of units in each of the hidden layers. This number need not be fixed for both layers.

For classification of MNIST, M=10.  
"""
# Out:
# '\nThis is a classification model based on NN. Here, we use only dense layers with MNIST dataset.   \nTypically M <= N <= K. M is the number of classes. \nN is the number of features in each training or testing example. \nK is the number of units in each of the hidden layers. This number need not be fixed for both layers.\n\nFor classification of MNIST, M=10.  \n'

# %%
number_of_features = 28*28
number_of_units_in_hidden_layer = 40

#### load the MNIST dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
#### building the input vector from the 28x28 pixels

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

# normalizing the data
x_train /= 255
x_test /= 255

x_train = x_train.reshape(60000,784,1)
x_test  = x_test.reshape(10000,784,1)

# %%
# one-hot encoding (OHE)
y_train_OHE = []
for label in y_train:
    all_zero_temp , all_zero_temp[label] = 10*[0],1.0
    y_train_OHE.append(all_zero_temp)
y_train_OHE = np.asarray(y_train_OHE)

y_test_OHE = []
for label in y_test:
    all_zero_temp = 10*[0]
    all_zero_temp[label] = 1.0
    y_test_OHE.append(all_zero_temp)
y_test_OHE = np.asarray(y_test_OHE)

# %%
#### Construct the NN classification model
NN_classification_model = tf.keras.Sequential()

layer = layers.Reshape((784,), input_shape=(784,1))
NN_classification_model.add(layer)

# define layer
hidden_layer_1 = layers.Dense(units=number_of_units_in_hidden_layer,input_shape=(784,), activation='relu')
# add layer to the model
NN_classification_model.add(hidden_layer_1)
# define layer
output_layer = layers.Dense(units=10, activation='softmax')
# add layer to the model
NN_classification_model.add(output_layer)

# %%
#### compile the model
NN_classification_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics='accuracy')

#### train the model as below and report the training and test error
NN_classification_model.fit(x_train, y_train_OHE, epochs=100, batch_size = 100, verbose=1)
_,train_acc = NN_classification_model.evaluate(x_train, y_train_OHE)
_,test_acc = NN_classification_model.evaluate(x_test, y_test_OHE)
print("acc on training data = {} ; acc of testing data = {}".format(train_acc, test_acc))
# Out:
# Epoch 1/100
# 600/600 [==============================] - 2s 3ms/step - loss: 1.9968 - accuracy: 0.4684
# Epoch 2/100
# 600/600 [==============================] - 2s 3ms/step - loss: 1.2296 - accuracy: 0.7067
# Epoch 3/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.8505 - accuracy: 0.8041
# Epoch 4/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.6617 - accuracy: 0.8421
# Epoch 5/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.5532 - accuracy: 0.8637
# Epoch 6/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.4853 - accuracy: 0.8765
# Epoch 7/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.4402 - accuracy: 0.8845
# Epoch 8/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.4088 - accuracy: 0.8901
# Epoch 9/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.3858 - accuracy: 0.8950
# Epoch 10/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.3682 - accuracy: 0.8986
# Epoch 11/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.3547 - accuracy: 0.9007
# Epoch 12/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.3437 - accuracy: 0.9033
# Epoch 13/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.3346 - accuracy: 0.9050
# Epoch 14/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.3270 - accuracy: 0.9070
# Epoch 15/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.3204 - accuracy: 0.9079
# Epoch 16/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.3147 - accuracy: 0.9095
# Epoch 17/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.3095 - accuracy: 0.9111
# Epoch 18/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.3050 - accuracy: 0.9122
# Epoch 19/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.3011 - accuracy: 0.9135
# Epoch 20/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2973 - accuracy: 0.9142
# Epoch 21/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2939 - accuracy: 0.9151
# Epoch 22/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2908 - accuracy: 0.9163
# Epoch 23/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2879 - accuracy: 0.9169
# Epoch 24/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2852 - accuracy: 0.9181
# Epoch 25/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2824 - accuracy: 0.9185
# Epoch 26/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2804 - accuracy: 0.9189
# Epoch 27/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2779 - accuracy: 0.9200
# Epoch 28/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2758 - accuracy: 0.9204
# Epoch 29/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2735 - accuracy: 0.9213
# Epoch 30/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2715 - accuracy: 0.9213
# Epoch 31/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2695 - accuracy: 0.9222
# Epoch 32/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2674 - accuracy: 0.9225
# Epoch 33/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2655 - accuracy: 0.9229
# Epoch 34/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2637 - accuracy: 0.9235
# Epoch 35/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2619 - accuracy: 0.9241
# Epoch 36/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2600 - accuracy: 0.9247
# Epoch 37/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2586 - accuracy: 0.9250
# Epoch 38/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2568 - accuracy: 0.9258
# Epoch 39/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2552 - accuracy: 0.9257
# Epoch 40/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2536 - accuracy: 0.9265
# Epoch 41/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2520 - accuracy: 0.9270
# Epoch 42/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2504 - accuracy: 0.9270
# Epoch 43/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2487 - accuracy: 0.9277
# Epoch 44/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2472 - accuracy: 0.9281
# Epoch 45/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2458 - accuracy: 0.9285
# Epoch 46/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2444 - accuracy: 0.9286
# Epoch 47/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2430 - accuracy: 0.9295
# Epoch 48/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2417 - accuracy: 0.9296
# Epoch 49/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2403 - accuracy: 0.9305
# Epoch 50/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2389 - accuracy: 0.9303
# Epoch 51/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2373 - accuracy: 0.9311
# Epoch 52/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2361 - accuracy: 0.9312
# Epoch 53/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2347 - accuracy: 0.9314
# Epoch 54/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2334 - accuracy: 0.9319
# Epoch 55/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2319 - accuracy: 0.9327
# Epoch 56/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2305 - accuracy: 0.9324
# Epoch 57/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2291 - accuracy: 0.9332
# Epoch 58/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2277 - accuracy: 0.9337
# Epoch 59/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2261 - accuracy: 0.9344
# Epoch 60/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2246 - accuracy: 0.9342
# Epoch 61/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2228 - accuracy: 0.9358
# Epoch 62/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2212 - accuracy: 0.9360
# Epoch 63/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2195 - accuracy: 0.9366
# Epoch 64/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2179 - accuracy: 0.9368
# Epoch 65/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2162 - accuracy: 0.9374
# Epoch 66/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2146 - accuracy: 0.9376
# Epoch 67/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2129 - accuracy: 0.9383
# Epoch 68/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2112 - accuracy: 0.9387
# Epoch 69/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2096 - accuracy: 0.9391
# Epoch 70/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2079 - accuracy: 0.9396
# Epoch 71/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2065 - accuracy: 0.9403
# Epoch 72/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2049 - accuracy: 0.9408
# Epoch 73/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2033 - accuracy: 0.9411
# Epoch 74/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2017 - accuracy: 0.9419
# Epoch 75/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.2000 - accuracy: 0.9426
# Epoch 76/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.1987 - accuracy: 0.9426
# Epoch 77/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.1972 - accuracy: 0.9430
# Epoch 78/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.1958 - accuracy: 0.9435
# Epoch 79/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.1943 - accuracy: 0.9441
# Epoch 80/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.1931 - accuracy: 0.9446
# Epoch 81/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.1916 - accuracy: 0.9450
# Epoch 82/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.1902 - accuracy: 0.9454
# Epoch 83/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.1888 - accuracy: 0.9453
# Epoch 84/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.1875 - accuracy: 0.9456
# Epoch 85/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.1863 - accuracy: 0.9467
# Epoch 86/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.1849 - accuracy: 0.9470
# Epoch 87/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.1835 - accuracy: 0.9471
# Epoch 88/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.1825 - accuracy: 0.9471
# Epoch 89/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.1812 - accuracy: 0.9478
# Epoch 90/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.1800 - accuracy: 0.9488
# Epoch 91/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.1788 - accuracy: 0.9489
# Epoch 92/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.1775 - accuracy: 0.9489
# Epoch 93/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.1764 - accuracy: 0.9493
# Epoch 94/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.1752 - accuracy: 0.9499
# Epoch 95/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.1741 - accuracy: 0.9501
# Epoch 96/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.1729 - accuracy: 0.9505
# Epoch 97/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.1717 - accuracy: 0.9504
# Epoch 98/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.1708 - accuracy: 0.9510
# Epoch 99/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.1696 - accuracy: 0.9510
# Epoch 100/100
# 600/600 [==============================] - 2s 3ms/step - loss: 0.1684 - accuracy: 0.9516
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1676 - accuracy: 0.9521
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1822 - accuracy: 0.9478
# acc on training data = 0.9520833492279053 ; acc of testing data = 0.9477999806404114
